# %%
from Transformer import TransformerController
from Utils.SaveUtils import load_parameters
from Parameters import TrainingParameters
from Utils.PrintUtils import print_big
from Utils.DataUtils import *
import tensorflow as tf
import numpy as np

# %%
####### Show tensorboard
# %load_ext tensorboard
# %tensorboard --logdir logs/gradient_tape
# %tensorboard --logdir logs/gradient_tape --host localhost --port 8088

# %%
parameters = TrainingParameters()
tf.random.set_seed(parameters.dataset_split_seed)
np.random.seed(parameters.dataset_split_seed)
trainer = TransformerController(parameters = parameters)
# Out:
# ========================================
# | Running on /job:localhost/replica:0/task:0/device:CPU:0
# ========================================
#
# ========================================
# | Preprocessed data loaded successfully: ./datasets/preprocessed/BPI_Challenge_2012_with_resource/AOW
# ========================================

# %%
trainer.show_model_info()
# Out:
# Model: "predicting_next_transformer_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# predict_next_encoder (Predic multiple                  35008
# _________________________________________________________________
# dense_24 (Dense)             multiple                  858
# =================================================================
# Total params: 35,866
# Trainable params: 35,866
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(trainer.model.vocab.vocabs)
# Out:
# ['<PAD>', '<EOS>', '<SOS>', 'A_ACCEPTED_COMPLETE', 'A_ACTIVATED_COMPLETE', 'A_APPROVED_COMPLETE', 'A_CANCELLED_COMPLETE', 'A_DECLINED_COMPLETE', 'A_FINALIZED_COMPLETE', 'A_PARTLYSUBMITTED_COMPLETE', 'A_PREACCEPTED_COMPLETE', 'A_REGISTERED_COMPLETE', 'A_SUBMITTED_COMPLETE', 'O_ACCEPTED_COMPLETE', 'O_CANCELLED_COMPLETE', 'O_CREATED_COMPLETE', 'O_DECLINED_COMPLETE', 'O_SELECTED_COMPLETE', 'O_SENT_BACK_COMPLETE', 'O_SENT_COMPLETE', 'W_Afhandelen leads_COMPLETE', 'W_Beoordelen fraude_COMPLETE', 'W_Completeren aanvraag_COMPLETE', 'W_Nabellen incomplete dossiers_COMPLETE', 'W_Nabellen offertes_COMPLETE', 'W_Valideren aanvraag_COMPLETE']

# %%
test_acc = trainer.train()
# Out:
# ======================
#
# ========================================
# | Evaluation result | Loss [34.9955] | Accuracy [0.7823]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.7272] | Accuracy [0.7888]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9155] | Accuracy [0.7888]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.7133] | Accuracy [0.7835]
# ========================================
#
# ========================================
# | Start epoch 22
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9502] | Accuracy [0.7873]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0567] | Accuracy [0.7881]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.3782] | Accuracy [0.7913]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9014] | Accuracy [0.7900]
# ========================================
#
# ========================================
# | Start epoch 23
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1943] | Accuracy [0.7876]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.2072] | Accuracy [0.7758]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.4541] | Accuracy [0.7873]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.8960] | Accuracy [0.7888]
# ========================================
#
# ========================================
# | Start epoch 24
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4291] | Accuracy [0.7839]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1446] | Accuracy [0.7886]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0142] | Accuracy [0.7867]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9298] | Accuracy [0.7797]
# ========================================
#
# ========================================
# | Start epoch 25
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4927] | Accuracy [0.7875]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.7879] | Accuracy [0.7839]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.8434] | Accuracy [0.7878]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.4990] | Accuracy [0.7886]
# ========================================
#
# ========================================
# | Start epoch 26
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3293] | Accuracy [0.7861]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.8938] | Accuracy [0.7808]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.6065] | Accuracy [0.7897]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4852] | Accuracy [0.7836]
# ========================================
#
# ========================================
# | Start epoch 27
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.8862] | Accuracy [0.7793]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.7283] | Accuracy [0.7780]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.4226] | Accuracy [0.7908]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9920] | Accuracy [0.7884]
# ========================================
#
# ========================================
# | Start epoch 28
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1751] | Accuracy [0.7797]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9321] | Accuracy [0.7883]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.8749] | Accuracy [0.7890]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3174] | Accuracy [0.7866]
# ========================================
#
# ========================================
# | Start epoch 29
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.5704] | Accuracy [0.7816]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4108] | Accuracy [0.7862]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.8779] | Accuracy [0.7891]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0871] | Accuracy [0.7841]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1220] | Accuracy [0.7866]
# ========================================
#
# ========================================
# | Start epoch 30
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.6614] | Accuracy [0.7830]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9632] | Accuracy [0.7780]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0289] | Accuracy [0.7890]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9247] | Accuracy [0.7791]
# ========================================
#
# ========================================
# | Start epoch 31
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4918] | Accuracy [0.7876]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0970] | Accuracy [0.7833]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.6993] | Accuracy [0.7818]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.6343] | Accuracy [0.7833]
# ========================================
#
# ========================================
# | Start epoch 32
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0150] | Accuracy [0.7887]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0248] | Accuracy [0.7884]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.8430] | Accuracy [0.7862]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0021] | Accuracy [0.7921]
# ========================================
#
# ========================================
# | Start epoch 33
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3776] | Accuracy [0.7826]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1664] | Accuracy [0.7812]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.6069] | Accuracy [0.7905]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.2123] | Accuracy [0.7824]
# ========================================
#
# ========================================
# | Start epoch 34
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.9052] | Accuracy [0.7824]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0311] | Accuracy [0.7888]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9003] | Accuracy [0.7808]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0104] | Accuracy [0.7856]
# ========================================
#
# ========================================
# | Start epoch 35
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.6338] | Accuracy [0.7883]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.5273] | Accuracy [0.7779]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.2705] | Accuracy [0.7895]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4518] | Accuracy [0.7902]
# ========================================
#
# ========================================
# | Start epoch 36
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4543] | Accuracy [0.7696]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.2741] | Accuracy [0.7769]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.9282] | Accuracy [0.7908]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.1700] | Accuracy [0.7874]
# ========================================
#
# ========================================
# | Start epoch 37
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.6536] | Accuracy [0.7786]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3811] | Accuracy [0.7778]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1100] | Accuracy [0.7892]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.7374] | Accuracy [0.7835]
# ========================================
#
# ========================================
# | Start epoch 38
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.7857] | Accuracy [0.7820]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.5597] | Accuracy [0.7877]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.0107] | Accuracy [0.7908]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4252] | Accuracy [0.7849]
# ========================================
#
# ========================================
# | Start epoch 39
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.7881] | Accuracy [0.7870]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.5083] | Accuracy [0.7868]
# ========================================
#
# ========================================
# | Evaluation result | Loss [34.6915] | Accuracy [0.7909]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.2374] | Accuracy [0.7877]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3232] | Accuracy [0.7869]
# ========================================
#
# ========================================
# | Start epoch 40
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1937] | Accuracy [0.7876]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4820] | Accuracy [0.7818]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.1633] | Accuracy [0.7915]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4392] | Accuracy [0.7793]
# ========================================
#
# ========================================
# | Start epoch 41
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.5717] | Accuracy [0.7868]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.5804] | Accuracy [0.7731]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3675] | Accuracy [0.7911]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3562] | Accuracy [0.7858]
# ========================================
#
# ========================================
# | Start epoch 42
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.8334] | Accuracy [0.7828]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.0738] | Accuracy [0.7847]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.4171] | Accuracy [0.7901]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.6231] | Accuracy [0.7842]
# ========================================
#
# ========================================
# | Start epoch 43
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.2293] | Accuracy [0.7829]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.9239] | Accuracy [0.7879]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.5773] | Accuracy [0.7873]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.0723] | Accuracy [0.7889]
# ========================================
#
# ========================================
# | Start epoch 44
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.4520] | Accuracy [0.7819]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.0002] | Accuracy [0.7863]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.9074] | Accuracy [0.7795]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.8215] | Accuracy [0.7870]
# ========================================
#
# ========================================
# | Start epoch 45
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.6512] | Accuracy [0.7887]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.9468] | Accuracy [0.7794]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.0761] | Accuracy [0.7856]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.6965] | Accuracy [0.7867]
# ========================================
#
# ========================================
# | Start epoch 46
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.2632] | Accuracy [0.7681]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.1655] | Accuracy [0.7764]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.7142] | Accuracy [0.7893]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.3735] | Accuracy [0.7896]
# ========================================
#
# ========================================
# | Start epoch 47
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.6565] | Accuracy [0.7774]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.1140] | Accuracy [0.7770]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.6273] | Accuracy [0.7883]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.0501] | Accuracy [0.7890]
# ========================================
#
# ========================================
# | Start epoch 48
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.7529] | Accuracy [0.7800]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.9945] | Accuracy [0.7868]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.7427] | Accuracy [0.7903]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.4515] | Accuracy [0.7870]
# ========================================
#
# ========================================
# | Start epoch 49
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.0232] | Accuracy [0.7887]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.1666] | Accuracy [0.7873]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.3637] | Accuracy [0.7840]
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.2743] | Accuracy [0.7863]
# ========================================
#
# ========================================
# | Evaluation result | Loss [35.7887] | Accuracy [0.7871]
# ========================================
#
# ========================================
# | Performing Testing ...
# ========================================
#
# ========================================
# | Evaluation result | Loss [36.7967] | Accuracy [0.7859]
# ========================================

# %%
trainer.save_training_result("TransformerController.ipynb", test_acc)
# Out:
# ========================================
# | Model saved successfully to: ./SavedModels/0.7859_BPI2012WithResource_TransformerActivityOnly_2021-06-23 03:25:19.491504
# ========================================
